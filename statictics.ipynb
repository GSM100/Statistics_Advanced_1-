# %% [markdown]
# 1) What is a random variable in probability theory?
# -    A random variable is a function that assigns numerical values to the outcomes of a random experiment. It can be discrete (taking specific values) or continuous (taking any value within a range).
#
#
#
#
# 2) What are the types of random variables?
#
# -    Discrete Random Variable (takes countable values, e.g., number of heads in a coin toss).
#
# -  Continuous Random Variable (takes any value in a given range, e.g., height of students in a class).
#
# 3)  What is the difference between discrete and continuous distributions?
#
# -    Discrete distribution represents probabilities for discrete random variables (e.g., binomial, Poisson).
#
# -  Continuous distribution represents probabilities over an interval (e.g., normal, exponential).
#
# 4) What are probability distribution functions (PDF)?
# -    A Probability Distribution Function describes the likelihood of a random variable taking specific values. For continuous distributions, the Probability Density Function (PDF) gives the relative likelihood.
#
# 5) How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#
# -   PDF gives the probability of a specific value.
#
# -  CDF gives the probability that a random variable is less than or equal to a given value.
#
# 6) What is a discrete uniform distribution?
# -  A discrete uniform distribution is where all outcomes have an equal probability.
#
#  Example: Rolling a fair die (each face has a probability of 1/6).
#
# 7) What are the key properties of a Bernoulli distribution?
#
# -  It has two possible outcomes (Success = 1, Failure = 0).
#
# -  Probability of success: 𝑝 , Probability of failure: 1−p.
#
# -  Mean = p, Variance =  p(1-p)
#
# 8) What is the binomial distribution, and how is it used in probability?
#
# -  The binomial distribution models the number of successes in
# 𝑛
# n independent trials of a Bernoulli experiment. Its formula is:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# where
# 𝑘
# k is the number of successes.
#
# 9)What is the Poisson distribution and where is it applied?
#
# -  It models the number of events occurring in a fixed interval, given a constant mean rate
# 𝜆
# λ. Used in queueing systems, biology, and telecommunications.
#
# 10) What is a continuous uniform distribution?
# -  A distribution where all values within a given range are equally probable. Example: Random selection between 0 and 1.
#
# 11) What are the characteristics of a normal distribution?
#
# -  Bell-shaped curve
#
# -  Symmetric around the mean
#
# -  Mean, median, and mode are equal
#
# -  Defined by mean 𝜇 and standard deviation  𝜎
#
#
# 12) What is the standard normal distribution, and why is it important?
#
# -  A normal distribution with mean 0 and standard deviation 1. Used for Z-scores and standardization.
#
# 13) What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# -  The CLT states that for a large sample size, the sampling distribution of the mean approaches a normal distribution, regardless of the population distribution.
#
# 14) How does the Central Limit Theorem relate to the normal distribution?
#
# -  It justifies the use of normal approximation for various statistical methods, even when the original data is not normally distributed.
#
# 15) What is the application of Z statistics in hypothesis testing?
#
# - Used when population standard deviation is known.
#
# Helps determine the probability of obtaining a test statistic under the null hypothesis.
#
# 16) How do you calculate a Z-score, and what does it represent?
#
# It measures how many standard deviations a value is from the mean.
#
# 17) What are point estimates and interval estimates in statistics?
#
# -  Point Estimate: A single value used to estimate a population parameter (e.g., sample mean).
#
# Interval Estimate: A range of values (confidence interval) that is likely to contain the population parameter.
#
# 18) What is the significance of confidence intervals in statistical analysis?
#
# -  Confidence intervals provide a range of plausible values for a population parameter with a certain level of confidence (e.g., 95%).
#
# 19) What is the relationship between a Z-score and a confidence interval?
#
# -  The Z-score determines the margin of error in confidence intervals. For a 95% confidence level, Z=1.96.
#
# 20) How are Z-scores used to compare different distributions?
#
# -  Z-scores standardize values from different distributions, making them comparable.
#
# 21) What are the assumptions for applying the Central Limit Theorem?
#
# -  Sample size should be large (usually
# 𝑛
# ≥
# 30
# n≥30).
#
# Samples should be independent.
#
# Population should not be too skewed if sample size is small.
#
# 22) What is the concept of expected value in a probability distribution?
#
# -  The expected value is the weighted average of all possible values:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑥
# 𝑃
# (
# 𝑥
# )
# E(X)=∑xP(x)
# It represents the long-term average outcome.
#
# 23) How does a probability distribution relate to the expected outcome of a random variable?
#
# -  The expected value of a random variable is derived from its probability distribution, guiding predictions about its behavior.

# %% [markdown]
# 1. Generate a random variable and display its value

# %%
import numpy as np

random_variable = np.random.rand()
print("Random Variable:", random_variable)
# Out:
# Random Variable: 0.12023129804384658

# %% [markdown]
# 2. Generate a discrete uniform distribution and plot the PMF

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

x = np.arange(1, 7)  # Example: rolling a fair die (1 to 6)
pmf = stats.randint.pmf(x, 1, 7)  # Discrete uniform PMF

plt.bar(x, pmf, color='blue', alpha=0.6)
plt.xlabel("Values")
plt.ylabel("Probability")
plt.title("PMF of Discrete Uniform Distribution")
plt.show()

# %% [markdown]
# 3. Function to calculate the PDF of a Bernoulli distribution

# %%
import scipy.stats as stats

def bernoulli_pdf(p):
    x = [0, 1]  # Bernoulli takes only 0 or 1
    pmf_values = stats.bernoulli.pmf(x, p)
    return dict(zip(x, pmf_values))

print(bernoulli_pdf(0.5))  # Example with p=0.5
# Out:
# {0: np.float64(0.5000000000000001), 1: np.float64(0.5)}

# %% [markdown]
# 4. Simulate a binomial distribution (n=10, p=0.5) and plot its histogram

# %%
n, p, size = 10, 0.5, 1000
data = np.random.binomial(n, p, size)

plt.hist(data, bins=np.arange(12)-0.5, density=True, alpha=0.6, color='g')
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.title("Binomial Distribution Histogram (n=10, p=0.5)")
plt.show()

# %% [markdown]
# 5. Create and visualize a Poisson distribution

# %%
lambda_val = 4
poisson_data = np.random.poisson(lambda_val, 1000)

plt.hist(poisson_data, bins=15, density=True, alpha=0.6, color='orange')
plt.xlabel("Occurrences")
plt.ylabel("Frequency")
plt.title("Poisson Distribution (λ=4)")
plt.show()

# %% [markdown]
# 6. Calculate and plot the CDF of a discrete uniform distribution

# %%
cdf = stats.randint.cdf(x, 1, 7)

plt.step(x, cdf, where='mid', color='red')
plt.xlabel("Values")
plt.ylabel("Cumulative Probability")
plt.title("CDF of Discrete Uniform Distribution")
plt.show()

# %% [markdown]
# 7. Generate and visualize a continuous uniform distribution

# %%
data = np.random.uniform(0, 10, 1000)

plt.hist(data, bins=20, density=True, color='purple', alpha=0.6)
plt.xlabel("Values")
plt.ylabel("Density")
plt.title("Continuous Uniform Distribution")
plt.show()

# %% [markdown]
# 8. Simulate data from a normal distribution and plot its histogram

# %%
mu, sigma = 0, 1
normal_data = np.random.normal(mu, sigma, 1000)

plt.hist(normal_data, bins=30, density=True, alpha=0.6, color='blue')
plt.xlabel("Values")
plt.ylabel("Density")
plt.title("Histogram of Normal Distribution")
plt.show()

# %% [markdown]
# 9. Function to calculate Z-scores from a dataset and plot them

# %%
def calculate_z_scores(data):
    return (data - np.mean(data)) / np.std(data)

data = np.random.normal(50, 10, 1000)
z_scores = calculate_z_scores(data)

plt.hist(z_scores, bins=30, color='cyan', alpha=0.6)
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.title("Z-score Distribution")
plt.show()

# %% [markdown]
# 10. Implement the Central Limit Theorem for a non-normal distribution

# %%
samples = 1000
sample_size = 30
population = np.random.exponential(scale=2, size=10000)  # Non-normal population

sample_means = [np.mean(np.random.choice(population, sample_size)) for _ in range(samples)]

plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='green')
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Central Limit Theorem Demonstration")
plt.show()

# %% [markdown]
# 15. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem

# %%
import numpy as np
import matplotlib.pyplot as plt

population = np.random.normal(loc=50, scale=15, size=10000)  # Normal distribution
sample_means = [np.mean(np.random.choice(population, 30)) for _ in range(1000)]  # Sample means

plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='green')
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Central Limit Theorem Verification")
plt.show()

# %% [markdown]
# 16. Function to calculate and plot the standard normal distribution (mean = 0, std = 1)

# %%
import scipy.stats as stats

x = np.linspace(-4, 4, 1000)
pdf = stats.norm.pdf(x, loc=0, scale=1)

plt.plot(x, pdf, color='blue')
plt.xlabel("X")
plt.ylabel("Probability Density")
plt.title("Standard Normal Distribution (μ=0, σ=1)")
plt.show()

# %% [markdown]
# 17. Generate binomial random variables and calculate probabilities

# %%
n, p, size = 10, 0.5, 1000
binomial_data = np.random.binomial(n, p, size)
unique, counts = np.unique(binomial_data, return_counts=True)
probabilities = counts / size

plt.bar(unique, probabilities, color='purple', alpha=0.6)
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.title("Binomial Distribution")
plt.show()

# %% [markdown]
# 18. Calculate the Z-score for a data point and compare to standard normal

# %%
def z_score(x, mean, std):
    return (x - mean) / std

data = np.random.normal(50, 10, 1000)
z_scores = z_score(data, np.mean(data), np.std(data))

plt.hist(z_scores, bins=30, color='cyan', alpha=0.6)
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.title("Z-score Distribution")
plt.show()

# %% [markdown]
# 19. Implement hypothesis testing using Z-statistics

# %%
from scipy.stats import norm

sample = np.random.normal(50, 10, 30)
pop_mean = 50
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
z_stat = (sample_mean - pop_mean) / (sample_std / np.sqrt(len(sample)))
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Z-Statistic: {z_stat}, P-Value: {p_value}")
# Out:
# Z-Statistic: 0.3904623711696629, P-Value: 0.6961946749216179

# %% [markdown]
# 20. Create a confidence interval for a dataset

# %%
import scipy.stats as stats

sample = np.random.normal(50, 10, 30)
confidence = 0.95
mean, sem = np.mean(sample), stats.sem(sample)
interval = stats.t.interval(confidence, len(sample)-1, loc=mean, scale=sem)

print(f"95% Confidence Interval: {interval}")
# Out:
# 95% Confidence Interval: (np.float64(47.26589329183334), np.float64(54.00995663997491))

# %% [markdown]
# 21. Generate normal data and interpret the confidence interval

# %%
sample = np.random.normal(50, 10, 30)
mean, sem = np.mean(sample), stats.sem(sample)
interval = stats.t.interval(0.95, len(sample)-1, loc=mean, scale=sem)

print(f"Sample Mean: {mean}, 95% Confidence Interval: {interval}")
# Out:
# Sample Mean: 51.156460305574726, 95% Confidence Interval: (np.float64(47.228368323642385), np.float64(55.084552287507066))

# %% [markdown]
# 22. Calculate and visualize the PDF of a normal distribution

# %%
x = np.linspace(-4, 4, 1000)
pdf = stats.norm.pdf(x, loc=0, scale=1)

plt.plot(x, pdf, color='red')
plt.xlabel("X")
plt.ylabel("Probability Density")
plt.title("Normal Distribution PDF")
plt.show()

# %% [markdown]
# 23. Calculate and interpret the CDF of a Poisson distribution

# %%
lambda_val = 4
x = np.arange(0, 15)
cdf = stats.poisson.cdf(x, lambda_val)

plt.step(x, cdf, where='mid', color='orange')
plt.xlabel("X")
plt.ylabel("Cumulative Probability")
plt.title("Poisson Distribution CDF")
plt.show()

# %% [markdown]
# 24. Simulate a random variable using continuous uniform distribution

# %%
data = np.random.uniform(0, 10, 1000)
expected_value = np.mean(data)
print("Expected Value:", expected_value)
# Out:
# Expected Value: 4.929802749788102

# %% [markdown]
# 25. Compare the standard deviations of two datasets

# %%
data1 = np.random.normal(50, 10, 1000)
data2 = np.random.normal(60, 15, 1000)

std1, std2 = np.std(data1), np.std(data2)
print(f"Standard Deviation of Dataset 1: {std1}")
print(f"Standard Deviation of Dataset 2: {std2}")

plt.hist(data1, bins=30, alpha=0.6, label="Dataset 1")
plt.hist(data2, bins=30, alpha=0.6, label="Dataset 2")
plt.legend()
plt.title("Comparison of Standard Deviations")
plt.show()
# Out:
# Standard Deviation of Dataset 1: 10.11243122486854
# Standard Deviation of Dataset 2: 14.37088465850858

# %% [markdown]
# 26. Calculate range and interquartile range (IQR)

# %%
data = np.random.normal(50, 10, 1000)
range_val = np.max(data) - np.min(data)
iqr = np.percentile(data, 75) - np.percentile(data, 25)

print(f"Range: {range_val}, IQR: {iqr}")
# Out:
# Range: 59.793814844880565, IQR: 13.691551324687133

# %% [markdown]
# 27. Implement Z-score normalization and visualize transformation

# %%
def z_score_normalization(data):
    return (data - np.mean(data)) / np.std(data)

data = np.random.normal(50, 10, 1000)
normalized_data = z_score_normalization(data)

plt.hist(normalized_data, bins=30, color='blue', alpha=0.6)
plt.xlabel("Z-score Normalized Values")
plt.ylabel("Frequency")
plt.title("Z-score Normalization")
plt.show()

# %% [markdown]
# 28. Calculate skewness and kurtosis of a normal dataset

# %%
from scipy.stats import skew, kurtosis

data = np.random.normal(50, 10, 1000)
skewness = skew(data)
kurt = kurtosis(data)

print(f"Skewness: {skewness}, Kurtosis: {kurt}")
# Out:
# Skewness: 0.10942731669736323, Kurtosis: -0.10188735395142867
